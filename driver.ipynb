# %% [markdown]
# # Imports and settings

# %%
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
# Global parameters
MODEL_NAME = "distilbert-base-uncased"

# %% [markdown]
# # Load and process data

# %%
from utils.pre_processing import combine_scraped_data
from config import data_paths

for phase in data_paths:
    metadata_name = data_paths[phase]['metadata']
    data_name = data_paths[phase]['data']
    combine_scraped_data(f'data/{data_name}', f'data/{metadata_name}', is_train=False)

# %%
from utils.pre_processing import clean_scraped_data

train = clean_scraped_data('data/train_processed.xlsx')
test = clean_scraped_data('data/test_processed.xlsx')
# Out:
#                  labels                                            title
# 0   marketing assistant                                        marketing
# 1   marketing assistant                                marketing advisor
# 2   marketing assistant                                  admin marketing
# 3   marketing assistant                          sales executive manager
# 4   marketing assistant                                 talent executive
# 5   marketing assistant  e-commerce senior executive (mandarin speaking)
# 6   marketing assistant                 digital marketing & social media
# 7   marketing assistant                       intern - digital marketing
# 8   marketing assistant             sales marketing development division
# 9   marketing assistant                              marketing executive
# 10  marketing assistant                   business & marketing executive

# %%
from utils.pre_processing import labels_indexes_mapping
# Create labels to indexes and indexes to labels dicts
label_to_idx , idx_to_label = labels_indexes_mapping(test)
# change the label to number
test.loc[:, 'labels'] = test.labels.apply(lambda x: label_to_idx.get(x))

# %%
from utils.dataloader import create_tokenizer_dataloader
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def tokenize_function(examples):
    return tokenizer(examples["title"], padding='max_length', max_length = 64, truncation=True)


train_dataloader = create_tokenizer_dataloader(test, tokenize_function)
# Out:
#   0%|          | 0/15463 [00:00<?, ?ex/s]

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=len(idx_to_label))
model
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=1369, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
from torch.optim import AdamW

optimizer = AdamW(model.parameters(), lr=5e-5)

# %%
from transformers import get_scheduler

num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=1369, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
from tqdm.auto import tqdm

progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
#   0%|          | 0/2901 [00:00<?, ?it/s]

# %%
output = tokenizer.decode(tokenized_data[3]['input_ids'].squeeze(), skip_special_tokens=True)
output
# Out:
# 'sales executive manager'

# %%
# metric = load_metric("accuracy")
model.eval()
for batch in train_dataloader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        outputs = model(**batch)

    logits = outputs.logits
    print(logits.shape)
    o = tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True)
    la = batch['labels'].tolist()
    predictions = torch.argmax(logits, dim=-1)
    pred = predictions.tolist()
    for t, p, l in zip(o, pred, la):
        print(f'title: {t},\n label: {idx_to_label.get(p)}, \n real: {idx_to_label.get(l)}')
        print('\n')
    print('--------------')
#     metric.add_batch(predictions=predictions, references=batch["labels"])
#
# metric.compute()
# Out:
# torch.Size([16, 1369])
# title: quranic teacher,
#  label: early years teacher,
#  real: tutor
#
#
# title: account staff / account assistant,
#  label: accounting assistant,
#  real: bookkeeper
#
#
# title: resort manager,
#  label: restaurant manager,
#  real: accommodation manager
#
#
# title: social media assistant,
#  label: online marketer,
#  real: online marketer
#
#
# title: project manager development,
#  label: project manager,
#  real: project manager
#
#
# title: transport planner ( thai speaker ),
#  label: car and van delivery driver,
#  real: transport planner
#
#
# title: fiber service & installer, kl # mal,
#  label: engineering assistant,
#  real: ICT network technician
#
#
# title: senior operational controller,
#  label: management assistant,
#  real: financial controller
#
#
# title: support & implementation manager,
#  label: project manager,
#  real: ICT help desk manager
#
#
# title: senior sales account manager ( wireline & logging service ),
#  label: sales assistant,
#  real: sales account manager
#
#
# title: lmw & shipping officer,
#  label: supply chain assistant,
#  real: non-vessel operating common carrier
#
#
# title: mdv apprenticeship program,
#  label: nurse responsible for general care,
#  real: credit analyst
#
#
# title: marketing executive ( 12 months contract ),
#  label: marketing assistant,
#  real: marketing assistant
#
#
# title: nodejs developer,
#  label: software developer,
#  real: software developer
#
#
# title: ceragem rawang customer care female,
#  label: customer service representative,
#  real: client relations manager
#
#
# title: scrum master / it project manager,
#  label: project manager,
#  real: ICT project manager
#
#
# --------------
# torch.Size([16, 1369])
# title: business development representative / japanese speaker,
#  label: sales assistant,
#  real: business consultant
#
#
# title: technical lead / solution architect ( s ),
#  label: software developer,
#  real: ICT system architect
#
#
# title: team leader ( technician ),
#  label: engineering assistant,
#  real: after-sales service technician
#
#
# title: finance & accounts executive,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: assistant superintendent, auxiliary police,
#  label: secretary,
#  real: police inspector
#
#
# title: supply chain management executive,
#  label: supply chain assistant,
#  real: supply chain assistant
#
#
# title: account assistant ( kota tinggi, johor ),
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: cleaner cum cooker,
#  label: building cleaner,
#  real: emergency response worker
#
#
# title: clerk cum assistant,
#  label: accounting assistant,
#  real: secretary
#
#
# title: vacancy sales support,
#  label: sales assistant,
#  real: sales support assistant
#
#
# title: pick - up rider 2,
#  label: motorcycle delivery person,
#  real: motorcycle delivery person
#
#
# title: rov supervisor,
#  label: maintenance and repair engineer,
#  real: machine operator supervisor
#
#
# title: dental surgery assistant / dental nurse,
#  label: nurse assistant,
#  real: dental chairside assistant
#
#
# title: nutritionist / feed formulation assistant,
#  label: nurse assistant,
#  real: animal feed nutritionist
#
#
# title: microservices developer,
#  label: software developer,
#  real: software developer
#
#
# title: internship software engineer,
#  label: software developer,
#  real: software developer
#
#
# --------------
# torch.Size([16, 1369])
# title: associate / consultant / senior consultant,
#  label: business consultant,
#  real: business consultant
#
#
# title: gis executive 2. 0,
#  label: data analyst,
#  real: geographic information systems specialist
#
#
# title: sales representative ( chinese ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: junior tax assistant,
#  label: tax advisor,
#  real: funeral attendant
#
#
# title: officer, warranty,
#  label: secretary,
#  real: insurance claims handler
#
#
# title: rider aeon seremban 2,
#  label: motorcycle delivery person,
#  real: motorcycle delivery person
#
#
# title: stock and billing clerk,
#  label: accounting assistant,
#  real: billing clerk
#
#
# title: resident advisor ( hostel warden ),
#  label: restaurant manager,
#  real: instrumentation engineer
#
#
# title: kindergarten teacher - little caliphs seksyen 19,
#  label: early years teacher,
#  real: early years teacher
#
#
# title: marketing manager, utar hospital ( perak ),
#  label: marketing assistant,
#  real: promotion manager
#
#
# title: finance officer,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: reception clerk,
#  label: secretary,
#  real: front line medical receptionist
#
#
# title: farm worker ( non - halal ),
#  label: factory hand,
#  real: livestock worker
#
#
# title: machine specialist ( male only ),
#  label: factory hand,
#  real: maintenance and repair engineer
#
#
# title: restaurant executive head chef,
#  label: kitchen assistant,
#  real: head chef
#
#
# title: software engineer ii, devops,
#  label: software developer,
#  real: software developer
#
#
# --------------
# torch.Size([16, 1369])
# title: senior php developer,
#  label: software developer,
#  real: software developer
#
#
# title: electrical & instrumentation engineer,
#  label: engineering assistant,
#  real: instrumentation engineer
#
#
# title: snr consultant – core business operations – financial services,
#  label: data analyst,
#  real: business consultant
#
#
# title: waste water treatment executive,
#  label: factory hand,
#  real: wastewater treatment technician
#
#
# title: laboratory assistant,
#  label: engineering assistant,
#  real: bacteriology technician
#
#
# title: forklift mechanic,
#  label: cargo vehicle driver,
#  real: maintenance and repair engineer
#
#
# title: senior audit ( accounting firm ),
#  label: accounting assistant,
#  real: financial auditor
#
#
# title: senior mechanical draftsman,
#  label: architectural drafter,
#  real: electromechanical drafter
#
#
# title: director of sales,
#  label: sales assistant,
#  real: destination manager
#
#
# title: customer success advocate,
#  label: customer service representative,
#  real: client relations manager
#
#
# title: sales executive ( part time ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: trainee solutions analyst,
#  label: data analyst,
#  real: ICT system analyst
#
#
# title: e - commerce coordinator ( ayer tawar ),
#  label: online marketer,
#  real: online marketer
#
#
# title: kerani kaunter ( counter clerk ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: executive learning & development,
#  label: early years teacher,
#  real: educational counsellor
#
#
# title: internship - sales,
#  label: sales assistant,
#  real: sales assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: excavator / bulldozer / compactor operator,
#  label: factory hand,
#  real: excavator operator
#
#
# title: embedded iot,
#  label: software developer,
#  real: design engineer
#
#
# title: data integration analyst,
#  label: data analyst,
#  real: database integrator
#
#
# title: rem sales operation executive,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: pipe welder ( steel works & pipe works ),
#  label: factory hand,
#  real: pipe welder
#
#
# title: installer cum lorry driver,
#  label: cargo vehicle driver,
#  real: building construction worker
#
#
# title: assistant sales and marketing manager,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: senior acountant,
#  label: accounting assistant,
#  real: sales account manager
#
#
# title: web designer,
#  label: web developer,
#  real: desktop publisher
#
#
# title: packaging supervisor,
#  label: factory hand,
#  real: packaging and filling machine operator
#
#
# title: sales executive - klang valley,
#  label: sales assistant,
#  real: advertising specialist
#
#
# title: report coordinator,
#  label: accounting analyst,
#  real: petroleum engineer
#
#
# title: assistant building manager,
#  label: management assistant,
#  real: building inspector
#
#
# title: crane operator,
#  label: factory hand,
#  real: mobile crane operator
#
#
# title: commis 3 ( pastry baker ),
#  label: kitchen assistant,
#  real: baker
#
#
# title: female sales assistant,
#  label: sales assistant,
#  real: sales assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: cutter operator - mdf board cutter operator,
#  label: factory hand,
#  real: paperboard products assembler
#
#
# title: general worker ( production ),
#  label: factory hand,
#  real: factory hand
#
#
# title: contract assistant,
#  label: secretary,
#  real: contract engineer
#
#
# title: staff nurse - operation theatre,
#  label: nurse responsible for general care,
#  real: nurse responsible for general care
#
#
# title: lorry driver cum installation leader,
#  label: cargo vehicle driver,
#  real: materials handler
#
#
# title: lead recruiter japanese / mandarin,
#  label: recruitment consultant,
#  real: recruitment consultant
#
#
# title: senior software engineer - c + +,
#  label: software developer,
#  real: software developer
#
#
# title: loan operation assistant,
#  label: debt collector,
#  real: loan officer
#
#
# title: vendor onboarding agent - japanese speaking,
#  label: sales assistant,
#  real: call centre agent
#
#
# title: officer, finance & administration,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: estate planner,
#  label: room attendant,
#  real: promotion assistant
#
#
# title: service specialist i - completion,
#  label: ICT technician,
#  real: petroleum engineer
#
#
# title: general worker noblelift,
#  label: factory hand,
#  real: factory hand
#
#
# title: mattress specialist,
#  label: kitchen assistant,
#  real: furniture upholsterer
#
#
# title: guidewire it specialist - frontend,
#  label: software developer,
#  real: software developer
#
#
# title: senior solution consultant,
#  label: software developer,
#  real: ICT system architect
#
#
# --------------
# torch.Size([16, 1369])
# title: graphic designer & content creation,
#  label: graphic designer,
#  real: graphic designer
#
#
# title: personal assistant cum admin,
#  label: secretary,
#  real: secretary
#
#
# title: sales and logistic coordinator,
#  label: sales assistant,
#  real: supply chain assistant
#
#
# title: project admin,
#  label: project manager,
#  real: management assistant
#
#
# title: general accounting & reporting senior analyst,
#  label: accounting analyst,
#  real: accounting analyst
#
#
# title: clerk ( production & store ),
#  label: sales assistant,
#  real: data entry clerk
#
#
# title: digital marketing executive ( based in selayang ),
#  label: online marketer,
#  real: online marketer
#
#
# title: cleaner bergerak,
#  label: building cleaner,
#  real: building cleaner
#
#
# title: sales & telemarketing,
#  label: online marketer,
#  real: online marketer
#
#
# title: java developer with apache camel,
#  label: software developer,
#  real: software developer
#
#
# title: branding executive,
#  label: online marketer,
#  real: brand manager
#
#
# title: penolong professor - physiology,
#  label: nurse assistant,
#  real: healthcare specialist lecturer
#
#
# title: laboratory assistant ( iets ),
#  label: engineering assistant,
#  real: biochemistry technician
#
#
# title: receiving cum store assistant,
#  label: sales assistant,
#  real: accounting assistant
#
#
# title: project manager ( wl ),
#  label: project manager,
#  real: project manager
#
#
# title: fitter - sabah based,
#  label: factory hand,
#  real: pipe welder
#
#
# --------------
# torch.Size([16, 1369])
# title: welding engineer,
#  label: engineering assistant,
#  real: welding engineer
#
#
# title: editor,
#  label: advertising copywriter,
#  real: editor-in-chief
#
#
# title: media / advertising sales executive,
#  label: online marketer,
#  real: advertising specialist
#
#
# title: system administrator,
#  label: ICT technician,
#  real: ICT security administrator
#
#
# title: digital marketing,
#  label: online marketer,
#  real: online marketer
#
#
# title: insurance consultant - agent,
#  label: nurse assistant,
#  real: insurance broker
#
#
# title: early years coordinator,
#  label: early years teacher,
#  real: early years teacher
#
#
# title: protege - rtw apprenticeship ( corporate office ),
#  label: software developer,
#  real: management assistant
#
#
# title: account assistant - internship position,
#  label: accounting assistant,
#  real: membership administrator
#
#
# title: executive ( registrar's office ),
#  label: office manager,
#  real: executive assistant
#
#
# title: senior company secretarial associate full time,
#  label: secretary,
#  real: secretary
#
#
# title: global engineering manager,
#  label: software developer,
#  real: foundry manager
#
#
# title: copier technician,
#  label: factory hand,
#  real: office equipment repair technician
#
#
# title: senior software engineer ( backend ),
#  label: software developer,
#  real: software developer
#
#
# title: smt technician,
#  label: engineering assistant,
#  real: cylinder filler
#
#
# title: toolmaker specialist,
#  label: factory hand,
#  real: tooling engineer
#
#
# --------------
# torch.Size([16, 1369])
# title: veterinary executive,
#  label: nurse assistant,
#  real: management assistant
#
#
# title: etl developer,
#  label: software developer,
#  real: software developer
#
#
# title: group capex controller,
#  label: software developer,
#  real: cost analyst
#
#
# title: qa manager - technical compliance,
#  label: project manager,
#  real: hazardous materials inspector
#
#
# title: maintenance engineer ( hw ),
#  label: maintenance and repair engineer,
#  real: maintenance and repair engineer
#
#
# title: finance assistant,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: kitchen crew / steward,
#  label: kitchen assistant,
#  real: kitchen assistant
#
#
# title: executive, halal & government relations,
#  label: secretary,
#  real: executive assistant
#
#
# title: assistant secretary ( personal ),
#  label: secretary,
#  real: domestic butler
#
#
# title: sales / sales executive,
#  label: sales assistant,
#  real: promotion assistant
#
#
# title: supervisor ( ref ),
#  label: factory hand,
#  real: machinery assembly coordinator
#
#
# title: executive ( instrument ),
#  label: engineering assistant,
#  real: instrumentation engineer
#
#
# title: manager, dealer development,
#  label: sales assistant,
#  real: motor vehicle shop manager
#
#
# title: male machine operator,
#  label: factory hand,
#  real: factory hand
#
#
# title: specialist, business support - supply chain ( sap pp ),
#  label: software developer,
#  real: ICT consultant
#
#
# title: sales assistant ( digital marketer ),
#  label: sales assistant,
#  real: online marketer
#
#
# --------------
# torch.Size([16, 1369])
# title: sap o2c specialist ( sd ),
#  label: ICT business analysis manager,
#  real: ICT business analysis manager
#
#
# title: assistant professor - actuarial science,
#  label: business lecturer,
#  real: business lecturer
#
#
# title: technical lead ( big data / hadoop ) - 1449565,
#  label: data analyst,
#  real: data analyst
#
#
# title: teaching vacancy - cambridge syllabus,
#  label: early years teacher,
#  real: curriculum administrator
#
#
# title: sap mm senior consultant - 1418438,
#  label: software developer,
#  real: ICT business analysis manager
#
#
# title: customer service & admin,
#  label: customer service representative,
#  real: office manager
#
#
# title: toolmaker trainee,
#  label: factory hand,
#  real: tool and die maker
#
#
# title: senior trainer physical therapy,
#  label: early years teacher,
#  real: physical education vocational teacher
#
#
# title: accounts & tax assistant,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: construction general workers / painter,
#  label: graphic designer,
#  real: construction general contractor
#
#
# title: process engineer,
#  label: project manager,
#  real: process engineer
#
#
# title: intern for sales & marketing,
#  label: sales assistant,
#  real: promotion assistant
#
#
# title: shipping officer,
#  label: supply chain assistant,
#  real: customs and excise officer
#
#
# title: production planning and control assistant,
#  label: management assistant,
#  real: purchase planner
#
#
# title: deputy general manager - corporate strategy & planning,
#  label: management assistant,
#  real: strategic planning manager
#
#
# title: senior retail consultant / supervisor,
#  label: sales assistant,
#  real: department store manager
#
#
# --------------
# torch.Size([16, 1369])
# title: senior executive, legal,
#  label: office manager,
#  real: case administrator
#
#
# title: nurse / medical assistant / paramedic,
#  label: nurse assistant,
#  real: nurse responsible for general care
#
#
# title: admin clerk / clerk,
#  label: accounting assistant,
#  real: bookkeeper
#
#
# title: assistant professor / associate professor / professor in english,
#  label: early years teacher,
#  real: university literature lecturer
#
#
# title: retail specialist,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: maintenance leader,
#  label: maintenance and repair engineer,
#  real: building cleaner
#
#
# title: assistant - baker,
#  label: kitchen assistant,
#  real: baker
#
#
# title: senior lecturer, it ( data science ),
#  label: business lecturer,
#  real: business lecturer
#
#
# title: fabrication engineer,
#  label: engineering assistant,
#  real: process engineer
#
#
# title: retail cleaner,
#  label: building cleaner,
#  real: domestic cleaner
#
#
# title: restaurant crew,
#  label: quick service restaurant crew member,
#  real: restaurant host/restaurant hostess
#
#
# title: kafka lead,
#  label: software developer,
#  real: software developer
#
#
# title: terengganu job - - ktcc mall ( online marketing ),
#  label: online marketer,
#  real: promoter
#
#
# title: accounts cum admin executive,
#  label: accounting assistant,
#  real: non-vessel operating common carrier
#
#
# title: social media planner,
#  label: online marketer,
#  real: community development officer
#
#
# title: apprenticeship - marketing,
#  label: marketing assistant,
#  real: marketing assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: care giver,
#  label: nurse assistant,
#  real: home care aide
#
#
# title: telemarketing promoter,
#  label: call centre agent,
#  real: call centre agent
#
#
# title: guru,
#  label: early years teacher,
#  real: university teaching assistant
#
#
# title: . net developer - 012,
#  label: software developer,
#  real: software developer
#
#
# title: door to door female cleaners,
#  label: building cleaner,
#  real: domestic cleaner
#
#
# title: hydrographic data processor,
#  label: data analyst,
#  real: data analyst
#
#
# title: lecturer, chiropractic ( physiologist / anatomist ),
#  label: nurse assistant,
#  real: physiologist
#
#
# title: graduate engineer,
#  label: engineering assistant,
#  real: pipeline engineer
#
#
# title: production control trainee ( graduated ),
#  label: factory hand,
#  real: sewing machinist
#
#
# title: partner account specialist - ( native taiwanese ),
#  label: accounting assistant,
#  real: online marketer
#
#
# title: automobile mechanic,
#  label: maintenance and repair engineer,
#  real: vehicle technician
#
#
# title: specialist, accounts payable ( thai speaking ),
#  label: accounting assistant,
#  real: accounting analyst
#
#
# title: java developer,
#  label: software developer,
#  real: software developer
#
#
# title: facility maintenace assistance manager,
#  label: office manager,
#  real: facilities manager
#
#
# title: social media content developer,
#  label: online marketer,
#  real: advertising copywriter
#
#
# title: license desk lead,
#  label: office manager,
#  real: licensing officer
#
#
# --------------
# torch.Size([16, 1369])
# title: malay teacher,
#  label: early years teacher,
#  real: curriculum administrator
#
#
# title: events cum administrative executive,
#  label: human resources officer,
#  real: event assistant
#
#
# title: donation processing assistant,
#  label: debt collector,
#  real: fundraising assistant
#
#
# title: warehouse assistant ( part - time ) # mvg,
#  label: factory hand,
#  real: warehouse order picker
#
#
# title: islamic financial advisor,
#  label: accounting analyst,
#  real: insurance broker
#
#
# title: sales promoter,
#  label: sales assistant,
#  real: promotion assistant
#
#
# title: retail operation officer / executive,
#  label: sales assistant,
#  real: marketing assistant
#
#
# title: desktop support engineer ( chinese speaking ),
#  label: software developer,
#  real: computer hardware engineer
#
#
# title: mandarin teacher,
#  label: early years teacher,
#  real: mathematics teacher at secondary school
#
#
# title: principal backend developer,
#  label: software developer,
#  real: software developer
#
#
# title: oil mill - mill engineer,
#  label: factory hand,
#  real: engineering assistant
#
#
# title: manufacturing engineer supervisor ( plastic / metal ),
#  label: engineering assistant,
#  real: process engineering technician
#
#
# title: social media content writer,
#  label: online marketer,
#  real: advertising copywriter
#
#
# title: van - driver,
#  label: cargo vehicle driver,
#  real: car and van delivery driver
#
#
# title: bank relationship manager # mct,
#  label: sales account manager,
#  real: bank account manager
#
#
# title: junior quantity surveyor,
#  label: quantity surveyor,
#  real: quantity surveyor
#
#
# --------------
# torch.Size([16, 1369])
# title: testing manager,
#  label: project manager,
#  real: construction engineer
#
#
# title: project engineer ( acmv ),
#  label: project manager,
#  real: process engineer
#
#
# title: banquet manager,
#  label: restaurant manager,
#  real: venue director
#
#
# title: fresh graduates,
#  label: early years teacher,
#  real: ICT consultant
#
#
# title: auto - lathe plant manager,
#  label: maintenance and repair engineer,
#  real: project manager
#
#
# title: sales executive / product specialist,
#  label: sales assistant,
#  real: physiotherapist
#
#
# title: cnc milling programmer,
#  label: factory hand,
#  real: milling machine operator
#
#
# title: senior advisor, it network,
#  label: data analyst,
#  real: ICT security administrator
#
#
# title: anode rodding operator,
#  label: factory hand,
#  real: factory hand
#
#
# title: project assessment engineer,
#  label: project manager,
#  real: process engineer
#
#
# title: engineer - virtual design & construction ( vdc ),
#  label: design engineer,
#  real: 3D modeller
#
#
# title: corporate training manager,
#  label: human resources officer,
#  real: corporate training manager
#
#
# title: full stack web developer,
#  label: software developer,
#  real: web developer
#
#
# title: tooling technician,
#  label: engineering assistant,
#  real: tool and die maker
#
#
# title: senior accounts executive,
#  label: accounting assistant,
#  real: accounting analyst
#
#
# title: outlet crew - sunway putra mall,
#  label: quick service restaurant crew member,
#  real: quick service restaurant crew member
#
#
# --------------
# torch.Size([16, 1369])
# title: senior draughtsman / illustrator,
#  label: graphic designer,
#  real: computer-aided design operator
#
#
# title: telesales senior supervisor,
#  label: call centre agent,
#  real: call centre supervisor
#
#
# title: vehicle repair,
#  label: cargo vehicle driver,
#  real: tyre fitter
#
#
# title: executive - market research,
#  label: business consultant,
#  real: executive assistant
#
#
# title: vr & ar instructor,
#  label: software developer,
#  real: ICT network technician
#
#
# title: sales representative,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: internship - web developer,
#  label: software developer,
#  real: web developer
#
#
# title: hr cum account admin executive,
#  label: human resources officer,
#  real: human resources officer
#
#
# title: assistant manager,
#  label: office manager,
#  real: management assistant
#
#
# title: technical clerk - body shop,
#  label: sales assistant,
#  real: data entry supervisor
#
#
# title: senior. net software engineer,
#  label: software developer,
#  real: ICT consultant
#
#
# title: research assistant ( mandarin desk ),
#  label: management assistant,
#  real: political affairs officer
#
#
# title: collection & registry assistant,
#  label: factory hand,
#  real: funeral attendant
#
#
# title: agent elite development programme,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: social media executive ( bahasa malaysia ),
#  label: online marketer,
#  real: graphic designer
#
#
# title: property executive / building executive,
#  label: restaurant manager,
#  real: property assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: hairdresser,
#  label: hair stylist,
#  real: hairdresser assistant
#
#
# title: lead data engineer,
#  label: data analyst,
#  real: ICT intelligent systems designer
#
#
# title: operator 3 / mlvk,
#  label: factory hand,
#  real: factory hand
#
#
# title: ks treasures ( service crew ),
#  label: quick service restaurant crew member,
#  real: quick service restaurant crew member
#
#
# title: junior hr & admin executive,
#  label: human resources officer,
#  real: human resources officer
#
#
# title: client services executive,
#  label: customer service representative,
#  real: client relations manager
#
#
# title: cmdb process lead,
#  label: software developer,
#  real: software developer
#
#
# title: sap hxm senior business process payroll consultant,
#  label: software developer,
#  real: software manager
#
#
# title: senior analyst,
#  label: data analyst,
#  real: analytical chemist
#
#
# title: granite polisher specialist,
#  label: factory hand,
#  real: stone polisher
#
#
# title: management trainee - finance & accounts,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: on - site it technical support,
#  label: software developer,
#  real: ICT technician
#
#
# title: lorry driver / van,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: backend developer ( node js ),
#  label: software developer,
#  real: software developer
#
#
# title: production staff male only,
#  label: factory hand,
#  real: concrete products machine operator
#
#
# title: junior executive - internship,
#  label: management assistant,
#  real: management assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: graphics designer,
#  label: graphic designer,
#  real: graphic designer
#
#
# title: driver lorry gdl d,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: site lorry driver,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: on - site technician,
#  label: engineering assistant,
#  real: telecommunications technician
#
#
# title: senior human resources manager,
#  label: human resources officer,
#  real: human resources assistant
#
#
# title: social media marketing executive,
#  label: online marketer,
#  real: online marketer
#
#
# title: techinical assistant crew,
#  label: engineering assistant,
#  real: after-sales service technician
#
#
# title: project manager ( video games ),
#  label: project manager,
#  real: project manager
#
#
# title: sr design authority - middleware,
#  label: software developer,
#  real: enterprise architect
#
#
# title: catering coordinator,
#  label: kitchen assistant,
#  real: kitchen assistant
#
#
# title: autocad draughtsman,
#  label: architectural drafter,
#  real: furniture designer
#
#
# title: accounting admin,
#  label: accounting assistant,
#  real: billing clerk
#
#
# title: shipping manager,
#  label: supply chain assistant,
#  real: vessel operations coordinator
#
#
# title: machine operator ( stamping machine ),
#  label: factory hand,
#  real: machine operator supervisor
#
#
# title: rf manager,
#  label: project manager,
#  real: integration engineer
#
#
# title: online sales & marketing,
#  label: online marketer,
#  real: online sales channel manager
#
#
# --------------
# torch.Size([16, 1369])
# title: project manager,
#  label: project manager,
#  real: project manager
#
#
# title: project management ( intern ),
#  label: project manager,
#  real: project manager
#
#
# title: program trainer,
#  label: early years teacher,
#  real: corporate trainer
#
#
# title: full stack web developer,
#  label: software developer,
#  real: software developer
#
#
# title: senior hr shared services administrator ( taa ),
#  label: human resources officer,
#  real: human resources officer
#
#
# title: officer, customer experience,
#  label: customer service representative,
#  real: customer service representative
#
#
# title: account & admin ( new business & operation dept ),
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: inside sales executive ( it services ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: merchant acquisition consultant ( 6 months contract ),
#  label: sales assistant,
#  real: sales account manager
#
#
# title: vice president business development,
#  label: business consultant,
#  real: operations manager
#
#
# title: marketing assistant / executive,
#  label: marketing assistant,
#  real: marketing assistant
#
#
# title: customer service rep,
#  label: customer service representative,
#  real: customer service representative
#
#
# title: supervisor & executive,
#  label: office manager,
#  real: marketing assistant
#
#
# title: electrical calibration engineer,
#  label: engineering assistant,
#  real: metrology technician
#
#
# title: electrical junior executive,
#  label: engineering assistant,
#  real: building construction worker
#
#
# title: product trainer,
#  label: early years teacher,
#  real: corporate trainer
#
#
# --------------
# torch.Size([16, 1369])
# title: child care coordinator,
#  label: early years teacher,
#  real: child care coordinator
#
#
# title: clerk of work - m & e construction engineer,
#  label: engineering assistant,
#  real: construction engineer
#
#
# title: store assistant cashier,
#  label: cashier,
#  real: cashier
#
#
# title: accounting assistant,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: customer service representative,
#  label: customer service representative,
#  real: customer service representative
#
#
# title: sales technician,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: teacher - kindergardens,
#  label: early years teacher,
#  real: early years teacher
#
#
# title: census worker ( based in oil palm estate, kedah ),
#  label: factory hand,
#  real: survey enumerator
#
#
# title: robotic tutor / content creator,
#  label: advertising copywriter,
#  real: tutor
#
#
# title: litigation clerk,
#  label: financial auditor,
#  real: legal administrative assistant
#
#
# title: r & d electrical engineer,
#  label: engineering assistant,
#  real: research engineer
#
#
# title: executive it suppport,
#  label: ICT technician,
#  real: ICT network technician
#
#
# title: assistant field engineer,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: costing & design engineer,
#  label: project manager,
#  real: budget analyst
#
#
# title: indoor sales assistant,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: financial manager,
#  label: accounting manager,
#  real: commercial director
#
#
# --------------
# torch.Size([16, 1369])
# title: advertising and promotion executive cum copywriter,
#  label: advertising copywriter,
#  real: advertising specialist
#
#
# title: lorry / forklift driver,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: internship ( operation ),
#  label: sales assistant,
#  real: sales engineer
#
#
# title: online marketeer,
#  label: online marketer,
#  real: online marketer
#
#
# title: supervisor operations ( jempol ),
#  label: office manager,
#  real: foster care support worker
#
#
# title: jointer tm,
#  label: factory hand,
#  real: telecommunications technician
#
#
# title: state registered nurse,
#  label: nurse assistant,
#  real: nurse responsible for general care
#
#
# title: service cleaner,
#  label: building cleaner,
#  real: building cleaner
#
#
# title: tyre technician and mechanic,
#  label: maintenance and repair engineer,
#  real: vehicle technician
#
#
# title: kubernetes integration consultant,
#  label: software developer,
#  real: integration engineer
#
#
# title: sales coordinator / sales support,
#  label: sales assistant,
#  real: sales support assistant
#
#
# title: junior application developer for ms crm,
#  label: software developer,
#  real: software developer
#
#
# title: roto / prep artist,
#  label: graphic designer,
#  real: 3D modeller
#
#
# title: photography & videography,
#  label: graphic designer,
#  real: digital media designer
#
#
# title: cloud service operations engineer,
#  label: data analyst,
#  real: ICT network technician
#
#
# title: process mechanical engineer - 40106 ( contract ),
#  label: process engineer,
#  real: manufacturing engineer
#
#
# --------------
# torch.Size([16, 1369])
# title: strategic planner and government relations,
#  label: management assistant,
#  real: strategic planning manager
#
#
# title: production technical lighting junior engineer,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: devops consultant,
#  label: software developer,
#  real: security consultant
#
#
# title: head of technology,
#  label: ICT technician,
#  real: ICT business development manager
#
#
# title: receptionist / conveyancing clerk,
#  label: secretary,
#  real: conveyance clerk
#
#
# title: convertional turning,
#  label: factory hand,
#  real: metal planer operator
#
#
# title: accounts payable executive ( italian / spanish / french speaker ),
#  label: accounting assistant,
#  real: accounting analyst
#
#
# title: information technology manager,
#  label: data analyst,
#  real: ICT documentation manager
#
#
# title: after sales service technician services,
#  label: engineering assistant,
#  real: telecommunications technician
#
#
# title: rider aeon ipoh,
#  label: motorcycle delivery person,
#  real: motorcycle delivery person
#
#
# title: art & graphic designer,
#  label: graphic designer,
#  real: graphic designer
#
#
# title: production planner executive,
#  label: management assistant,
#  real: supply chain assistant
#
#
# title: accounts cum tax executive,
#  label: accounting assistant,
#  real: tax clerk
#
#
# title: finance manager ( cpa / acca / mia / micpa / icaew ),
#  label: accounting assistant,
#  real: financial controller
#
#
# title: logistic clerk ( rawang - serendah ),
#  label: supply chain assistant,
#  real: supply chain assistant
#
#
# title: m & e site supervisors cum service technicians,
#  label: engineering assistant,
#  real: construction engineer
#
#
# --------------
# torch.Size([16, 1369])
# title: fashion model,
#  label: hair stylist,
#  real: fashion model
#
#
# title: car wash,
#  label: kitchen assistant,
#  real: vehicle cleaner
#
#
# title: technician factory,
#  label: engineering assistant,
#  real: process engineering technician
#
#
# title: assistant branch manager ( pahang ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: sales specialist,
#  label: sales assistant,
#  real: telecommunications equipment specialised seller
#
#
# title: area supervisor - tealive sungai buloh area,
#  label: building cleaner,
#  real: restaurant manager
#
#
# title: water treatment site operator,
#  label: factory hand,
#  real: waste treatment engineer
#
#
# title: junior mechanical engineer,
#  label: engineering assistant,
#  real: mechanical engineering drafter
#
#
# title: bakery sales assistance,
#  label: sales assistant,
#  real: baking operator
#
#
# title: maintenance operator,
#  label: maintenance and repair engineer,
#  real: factory hand
#
#
# title: senior commercial executive,
#  label: sales assistant,
#  real: quantity surveyor
#
#
# title: senior associate professor,
#  label: business lecturer,
#  real: university teaching assistant
#
#
# title: microsoft developer,
#  label: software developer,
#  real: software developer
#
#
# title: social media and marketing executive,
#  label: online marketer,
#  real: online sales channel manager
#
#
# title: kindergarten cleaner,
#  label: building cleaner,
#  real: emergency response worker
#
#
# title: delivery rider,
#  label: car and van delivery driver,
#  real: motorcycle delivery person
#
#
# --------------
# torch.Size([16, 1369])
# title: assistant company secretary,
#  label: secretary,
#  real: secretary
#
#
# title: costing / qs assistant,
#  label: accounting assistant,
#  real: quantity surveyor
#
#
# title: lorry driver cum welder assistant,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: technician ( air - cond ),
#  label: engineering assistant,
#  real: calibration technician
#
#
# title: associate, audit and assurance ( kl office ),
#  label: financial auditor,
#  real: financial auditor
#
#
# title: project technical manager,
#  label: project manager,
#  real: project manager
#
#
# title: test engineer ( fresh graduate ) - 40368 ( contract ),
#  label: engineering assistant,
#  real: manufacturing engineer
#
#
# title: logistic operator,
#  label: supply chain assistant,
#  real: freight transport dispatcher
#
#
# title: mcm - customer service officer,
#  label: customer service representative,
#  real: call centre agent
#
#
# title: financial assistant,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: assistant cake designer,
#  label: graphic designer,
#  real: confectioner
#
#
# title: e - commerce online marketer,
#  label: online marketer,
#  real: online marketer
#
#
# title: sales associate ( motor lubricant ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: recreation executive,
#  label: aesthetician,
#  real: sports programme coordinator
#
#
# title: sales & shipping clerk,
#  label: sales assistant,
#  real: sales support assistant
#
#
# title: healthcare assistant / nursing assistant,
#  label: nurse assistant,
#  real: nurse assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: assistant secretary cum social media writer,
#  label: online marketer,
#  real: online marketer
#
#
# title: finance, assistant manager,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: vending machine operator,
#  label: factory hand,
#  real: vending machine operator
#
#
# title: welding,
#  label: factory hand,
#  real: welding engineer
#
#
# title: customer services & dental assistance,
#  label: customer service representative,
#  real: dental chairside assistant
#
#
# title: retail sales promoter,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: operator ( assembly ),
#  label: factory hand,
#  real: factory hand
#
#
# title: lorry assistant wanted ( 3 ton ),
#  label: cargo vehicle driver,
#  real: factory hand
#
#
# title: customer receptionist,
#  label: customer service representative,
#  real: customer service representative
#
#
# title: principal msu kids,
#  label: early years teacher,
#  real: nursery school head teacher
#
#
# title: mechanic ( electrical ),
#  label: maintenance and repair engineer,
#  real: electrical mechanic
#
#
# title: imam / bilal,
#  label: early years teacher,
#  real: pastoral worker
#
#
# title: soc security analyst,
#  label: data analyst,
#  real: security consultant
#
#
# title: project site supervisor,
#  label: project manager,
#  real: construction general contractor
#
#
# title: apprentice ( perantis ) in cooking / bakery / pastry,
#  label: kitchen assistant,
#  real: kitchen assistant
#
#
# title: technician installer,
#  label: maintenance and repair engineer,
#  real: lift technician
#
#
# --------------
# torch.Size([16, 1369])
# title: marketing expert ( cantonese speaker ),
#  label: marketing assistant,
#  real: online marketer
#
#
# title: shipping executive, taman desa # mal,
#  label: supply chain assistant,
#  real: move coordinator
#
#
# title: shipping operation executive - sibu,
#  label: supply chain assistant,
#  real: engineering assistant
#
#
# title: flange and lip die specialist ),
#  label: factory hand,
#  real: tool and die maker
#
#
# title: it assistant ( apprentice ),
#  label: ICT technician,
#  real: ICT business analyst
#
#
# title: marketing online,
#  label: online marketer,
#  real: online marketer
#
#
# title: assistant manager, sodemc,
#  label: management assistant,
#  real: executive assistant
#
#
# title: assistant surveyor,
#  label: quantity surveyor,
#  real: surveying technician
#
#
# title: application support consultant,
#  label: software developer,
#  real: ICT consultant
#
#
# title: loader operator,
#  label: factory hand,
#  real: stagehand
#
#
# title: messenger / delivery boy,
#  label: car and van delivery driver,
#  real: postman/postwoman
#
#
# title: fetus plumber,
#  label: factory hand,
#  real: plumber
#
#
# title: k2 senior developer,
#  label: software developer,
#  real: ICT consultant
#
#
# title: lorry driver cum store assistant, pemandu lori dan,
#  label: cargo vehicle driver,
#  real: moving truck driver
#
#
# title: pg branch manager cum engineering manager ( japanese speaker ),
#  label: project manager,
#  real: design engineer
#
#
# title: hv battery management system engineer,
#  label: software developer,
#  real: ICT network technician
#
#
# --------------
# torch.Size([16, 1369])
# title: insurance claims manager,
#  label: nurse assistant,
#  real: insurance claims manager
#
#
# title: dental clinic assistant,
#  label: nurse assistant,
#  real: dental chairside assistant
#
#
# title: vacancy - winch technician,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: software developer,
#  label: software developer,
#  real: software developer
#
#
# title: driver ( based at sandakan town office ),
#  label: cargo vehicle driver,
#  real: postman/postwoman
#
#
# title: stock,
#  label: accounting assistant,
#  real: stock trader
#
#
# title: administrative and human resource junior executive,
#  label: human resources officer,
#  real: human resources officer
#
#
# title: event executive ( cum graphic designer, copywriter ),
#  label: graphic designer,
#  real: event assistant
#
#
# title: desktop application developer ( airamap ) intern,
#  label: software developer,
#  real: software developer
#
#
# title: operator ( tebrau 2 ),
#  label: factory hand,
#  real: factory hand
#
#
# title: data entry assistant,
#  label: data analyst,
#  real: data entry clerk
#
#
# title: cashier admin assistant ( pj ss & old klang road ),
#  label: cashier,
#  real: cashier
#
#
# title: account executive at finance department,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: admin pa,
#  label: secretary,
#  real: secretary
#
#
# title: beauty / theraphist,
#  label: hair stylist,
#  real: aesthetician
#
#
# title: lorry driver - night shift,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# --------------
# torch.Size([16, 1369])
# title: promoter @ parkson ioi city, putrajaya,
#  label: sales assistant,
#  real: promoter
#
#
# title: ui / ux designer,
#  label: graphic designer,
#  real: user interface designer
#
#
# title: intern - human resource,
#  label: human resources officer,
#  real: human resources assistant
#
#
# title: sap bw experts,
#  label: ICT business analysis manager,
#  real: ICT business analysis manager
#
#
# title: lorry driver ( 10 ton ),
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: trainees,
#  label: factory hand,
#  real: agricultural raw materials, seeds and animal feeds distribution manager
#
#
# title: pendidik / pengasuh taska ( playschool tvra ),
#  label: factory hand,
#  real: early years teacher
#
#
# title: junior corporate sales,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: technician stamping,
#  label: engineering assistant,
#  real: maintenance and repair engineer
#
#
# title: denture technician,
#  label: factory hand,
#  real: dental technician
#
#
# title: structural test technician,
#  label: engineering assistant,
#  real: calibration technician
#
#
# title: wwtp assistant,
#  label: factory hand,
#  real: wastewater treatment technician
#
#
# title: general staff komai - so shop wangsa maju,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: digital marketing apprentice,
#  label: online marketer,
#  real: promotion assistant
#
#
# title: assistant operator,
#  label: factory hand,
#  real: semiconductor processor
#
#
# title: navision ( nav ) developer,
#  label: software developer,
#  real: software developer
#
#
# --------------
# torch.Size([16, 1369])
# title: assembly technician 5,
#  label: engineering assistant,
#  real: industrial machinery assembler
#
#
# title: assistant branch manager,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: courier / kurier van driver dengan / with gdl licence. 35 below,
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: hradmin executive,
#  label: human resources officer,
#  real: human resources officer
#
#
# title: lecturer in mathematics,
#  label: early years teacher,
#  real: business lecturer
#
#
# title: insurance telemarketing,
#  label: call centre agent,
#  real: call centre agent
#
#
# title: software programmer ( asp. net ),
#  label: software developer,
#  real: software developer
#
#
# title: mobile phone repair technician,
#  label: maintenance and repair engineer,
#  real: mobile phone repair technician
#
#
# title: sales assistant ( nationwide ),
#  label: sales assistant,
#  real: promotion assistant
#
#
# title: ai technician,
#  label: engineering assistant,
#  real: ICT network technician
#
#
# title: account executive ( 3 months contract ),
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: business consultant - transformation,
#  label: business consultant,
#  real: business consultant
#
#
# title: assistant physiotherapist / physiotherapist,
#  label: nurse assistant,
#  real: physiotherapist
#
#
# title: secretary,
#  label: secretary,
#  real: secretary
#
#
# title: senior data analyst,
#  label: data analyst,
#  real: data analyst
#
#
# title: mould automation engineer,
#  label: maintenance and repair engineer,
#  real: moulding machine technician
#
#
# --------------
# torch.Size([16, 1369])
# title: nq international trade department : administrative special,
#  label: sales assistant,
#  real: trade development officer
#
#
# title: hr personnel,
#  label: human resources officer,
#  real: human resources officer
#
#
# title: automotive operator,
#  label: factory hand,
#  real: factory hand
#
#
# title: assistant / officer, accounts ( ar ),
#  label: accounting assistant,
#  real: sales support assistant
#
#
# title: application support ( junior ),
#  label: software developer,
#  real: software analyst
#
#
# title: data entry clerk ( temporary ),
#  label: data entry clerk,
#  real: data entry clerk
#
#
# title: sale assistance,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: chief wire - edm / fitter,
#  label: factory hand,
#  real: fitter and turner
#
#
# title: service desk engineer,
#  label: software developer,
#  real: ICT help desk agent
#
#
# title: executive - logistics,
#  label: supply chain assistant,
#  real: logistics analyst
#
#
# title: 3rd engineer,
#  label: engineering assistant,
#  real: marine engineer
#
#
# title: temporary marketing assistant,
#  label: marketing assistant,
#  real: marketing assistant
#
#
# title: customer service cum financial advisor,
#  label: customer service representative,
#  real: relationship banking manager
#
#
# title: sales and marketing ( internship ),
#  label: sales assistant,
#  real: promotion assistant
#
#
# title: software application engineer,
#  label: software developer,
#  real: software developer
#
#
# title: product senior executive / executive,
#  label: engineering assistant,
#  real: design engineer
#
#
# --------------
# torch.Size([16, 1369])
# title: jigs, moulds & mechanisation specialist,
#  label: factory hand,
#  real: moulding machine operator
#
#
# title: waiter & waitress,
#  label: kitchen assistant,
#  real: restaurant host/restaurant hostess
#
#
# title: credit collection executive - singapore market,
#  label: debt collector,
#  real: debt collector
#
#
# title: management supervisor,
#  label: management assistant,
#  real: management assistant
#
#
# title: operation staff / supervisor,
#  label: office manager,
#  real: sales assistant
#
#
# title: global business development manager,
#  label: business consultant,
#  real: business developer
#
#
# title: retail assistant @ mytown shopping centre,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: islamic kindergarten teacher,
#  label: early years teacher,
#  real: early years teacher
#
#
# title: protege - quality control,
#  label: project manager,
#  real: bacteriology technician
#
#
# title: technical assistance,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: admin executive,
#  label: office manager,
#  real: secretary
#
#
# title: regional support manager,
#  label: management assistant,
#  real: ICT help desk manager
#
#
# title: account & administration executive,
#  label: accounting assistant,
#  real: bookkeeper
#
#
# title: junior application engineer,
#  label: software developer,
#  real: ICT application configurator
#
#
# title: programme manager,
#  label: management assistant,
#  real: programme manager
#
#
# title: marketing executive ( senior executive ),
#  label: marketing assistant,
#  real: public relations manager
#
#
# --------------
# torch.Size([16, 1369])
# title: rpa software developer,
#  label: software developer,
#  real: software developer
#
#
# title: installer ( telecommunication ),
#  label: engineering assistant,
#  real: telecommunications technician
#
#
# title: video designer & camera operator,
#  label: graphic designer,
#  real: performance video designer
#
#
# title: management consultant,
#  label: management assistant,
#  real: business consultant
#
#
# title: machine operater,
#  label: factory hand,
#  real: print folding operator
#
#
# title: superintendent ( ref ),
#  label: factory hand,
#  real: industrial machinery assembler
#
#
# title: apprentice for technician - rm1200 * | foc monthly activities,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: personal driver to director,
#  label: cargo vehicle driver,
#  real: private chauffeur
#
#
# title: aromatherapist,
#  label: nurse assistant,
#  real: aromatherapist
#
#
# title: material handler,
#  label: factory hand,
#  real: forklift operator
#
#
# title: instrument engineer ( 1 year contract ),
#  label: engineering assistant,
#  real: instrumentation engineer
#
#
# title: service consultant assistant,
#  label: data analyst,
#  real: funeral attendant
#
#
# title: quality control apprentice,
# ...
#
#
# title: management trainee - hr query management,
#  label: human resources officer,
#  real: human resources officer
#
#
# --------------
# torch.Size([16, 1369])
# title: head of live - streaming,
#  label: online marketer,
#  real: online sales channel manager
#
#
# title: driver and general worker,
#  label: cargo vehicle driver,
#  real: car and van delivery driver
#
#
# title: boilerman grade 2,
#  label: factory hand,
#  real: boiler operator
#
#
# title: building material sales agent,
#  label: sales assistant,
#  real: travel agent
#
#
# title: mineral exploration supervisor,
#  label: factory hand,
#  real: mineral processing engineer
#
#
# title: manufacutring supervisor,
#  label: factory hand,
#  real: machine operator supervisor
#
#
# title: firewatcher,
#  label: architectural drafter,
#  real: fire inspector
#
#
# title: installer cum technician,
#  label: maintenance and repair engineer,
#  real: after-sales service technician
#
#
# title: kitchen manager / executive,
#  label: kitchen assistant,
#  real: head chef
#
#
# title: general worker ( forklift operator ),
#  label: factory hand,
#  real: forklift operator
#
#
# title: compensation & benefits, hris specialist, apac,
#  label: human resources officer,
#  real: information manager
#
#
# title: jr accounts & admin,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: general clerk / sa,
#  label: accounting assistant,
#  real: office equipment repair technician
#
#
# title: chua cafe,
#  label: kitchen assistant,
#  real: cashier
#
#
# title: plywood technical specialist,
#  label: factory hand,
#  real: veneer grader
#
#
# title: operational supervisor,
#  label: office manager,
#  real: electrical equipment inspector
#
#
# --------------
# torch.Size([16, 1369])
# title: integrative doctor,
#  label: nurse assistant,
#  real: general practitioner
#
#
# title: software development,
#  label: software developer,
#  real: software developer
#
#
# title: sales and marketing executive ( jb branch ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: crew outlet,
#  label: quick service restaurant crew member,
#  real: kitchen assistant
#
#
# title: soa consultant ( api architect ),
#  label: software developer,
#  real: ICT system architect
#
#
# title: heavy equipment operator,
#  label: factory hand,
#  real: occupational driving instructor
#
#
# title: master data executive,
#  label: data analyst,
#  real: data entry supervisor
#
#
# title: sushi king sunway pyramid part time crew,
#  label: quick service restaurant crew member,
#  real: quick service restaurant crew member
#
#
# title: sales associate,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: printing machine operator / flexo,
#  label: factory hand,
#  real: flexographic press operator
#
#
# title: looking for accounts asst in kota kinabalu,
#  label: accounting assistant,
#  real: accounting assistant
#
#
# title: seo product optimisation specialist,
#  label: software developer,
#  real: search engine optimisation expert
#
#
# title: solutions architect manager,
#  label: software developer,
#  real: software architect
#
#
# title: senior manager - assurance ( tice energy ),
#  label: project manager,
#  real: financial auditor
#
#
# title: technical sales engineer - cloud,
#  label: software developer,
#  real: technical sales representative in electronic and telecommunications equipment
#
#
# title: pegawai ehwal ekonomi gred e41,
#  label: early years teacher,
#  real: civil service administrative officer
#
#
# --------------
# torch.Size([16, 1369])
# title: senior business intelligence developer,
#  label: software developer,
#  real: business intelligence manager
#
#
# title: senior retail executive,
#  label: sales assistant,
#  real: retail entrepreneur
#
#
# title: operation business consultant,
#  label: business consultant,
#  real: business consultant
#
#
# title: production line leader,
#  label: factory hand,
#  real: furniture assembler
#
#
# title: videographer cum video editor,
#  label: graphic designer,
#  real: camera operator
#
#
# title: marketing cum recruitment,
#  label: marketing assistant,
#  real: marketing assistant
#
#
# title: innovation officer,
#  label: data analyst,
#  real: tutor
#
#
# title: business process specialist,
#  label: project manager,
#  real: ICT business analyst
#
#
# title: bus process del sr analyst - korean,
#  label: project manager,
#  real: online community manager
#
#
# title: jr. executive, human resources ( hostel management ),
#  label: human resources officer,
#  real: human resources assistant
#
#
# title: senior executive, contract,
#  label: office manager,
#  real: quantity surveyor
#
#
# title: assistant qc inspector,
#  label: process engineering technician,
#  real: process engineering technician
#
#
# title: solar project & maintenance asst engineerintern,
#  label: maintenance and repair engineer,
#  real: engineering assistant
#
#
# title: lorry driver ( light truck ),
#  label: cargo vehicle driver,
#  real: cargo vehicle driver
#
#
# title: accounting clerk ( chinese ),
#  label: accounting assistant,
#  real: bookkeeper
#
#
# title: internship sales and marketing,
#  label: sales assistant,
#  real: marketing assistant
#
#
# --------------
# torch.Size([16, 1369])
# title: master data analyst ( emerging brands ),
#  label: data analyst,
#  real: data analyst
#
#
# title: electrical assistant,
#  label: engineering assistant,
#  real: electrical cable assembler
#
#
# title: team lead, client instructions ( vietnamese speaker ),
#  label: client relations manager,
#  real: client relations manager
#
#
# title: sport admin executive,
#  label: human resources officer,
#  real: sport administrator
#
#
# title: varnisher,
#  label: architectural drafter,
#  real: furniture finisher
#
#
# title: qa / qc inspector,
#  label: process engineering technician,
#  real: food safety inspector
#
#
# title: field work graduate trainee ( safety & health ),
#  label: engineering assistant,
#  real: petroleum engineer
#
#
# title: nurse / medical assistant needed,
#  label: nurse assistant,
#  real: nurse assistant
#
#
# title: retail sales associate ( sunway velocity ) part time,
#  label: sales assistant,
#  real: sales assistant
#
#
# title: manager, production,
#  label: factory hand,
#  real: project manager
#
#
# title: intermediate graphic designer,
#  label: graphic designer,
#  real: graphic designer
#
#
# title: dispatch cum office assistant,
#  label: call centre agent,
#  real: motorcycle delivery person
#
#
# title: e - commerce / digital marketing / digital salesman,
#  label: online marketer,
#  real: online marketer
#
#
# title: sales advisor ( native hindi speaker ),
#  label: sales assistant,
#  real: sales assistant
#
#
# title: costing & design engineer,
#  label: project manager,
#  real: cost analyst
#
#
# title: nursery teacher,
#  label: early years teacher,
#  real: early years teacher
#
#
# --------------
# torch.Size([16, 1369])
# title: operation assistant, engineering,
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: cook assistant,
#  label: kitchen assistant,
#  real: kitchen assistant
#
#
# title: medical doctor ( general practitioner ),
#  label: nurse assistant,
#  real: specialised doctor
#
#
# title: painter,
#  label: graphic designer,
#  real: construction painter
#
#
# title: creative graduate programme - internship,
#  label: graphic designer,
#  real: 3D modeller
#
#
# title: senior photographer & videographer cum editor,
#  label: graphic designer,
#  real: photographer
#
#
# title: project cost controller,
#  label: quantity surveyor,
#  real: budget analyst
#
#
# title: assistant environmental executive,
#  label: human resources officer,
#  real: air pollution analyst
#
#
# title: cashier & merchandiser,
#  label: cashier,
#  real: cashier
#
#
# title: laboratory assisstant,
#  label: engineering assistant,
#  real: machinery assembly coordinator
#
#
# title: restaurant manager,
#  label: restaurant manager,
#  real: restaurant manager
#
#
# title: pipe installer / gas pipe,
#  label: factory hand,
#  real: construction general contractor
#
#
# title: administrative manager,
#  label: office manager,
#  real: office manager
#
#
# title: instrument supervisor,
#  label: maintenance and repair engineer,
#  real: instrument technician
#
#
# title: etp operator,
#  label: factory hand,
#  real: shunter
#
#
# title: java developer # mvg,
#  label: software developer,
#  real: ICT system developer
#
#
# --------------
# torch.Size([16, 1369])
# title: technician quality assurance,
#  label: engineering assistant,
#  real: process engineering technician
#
#
# title: it engineering assistant,
#  label: software developer,
#  real: ICT consultant
#
#
# title: assistant engineer ( apprentice ),
#  label: engineering assistant,
#  real: engineering assistant
#
#
# title: manufacturing technician,
#  label: engineering assistant,
#  real: factory hand
#
#
# title: slickline operator,
#  label: factory hand,
#  real: petroleum engineer
#
#
# title: site supervisor / cashier,
#  label: cashier,
#  real: fuel station specialised seller
#
#
# title: senior engineer ( mes ),
#  label: engineering assistant,
#  real: executive assistant
#
#
# title: documentation executive,
#  label: data analyst,
#  real: file clerk
#
#
# title: state registered nurse,
#  label: nurse assistant,
#  real: specialist nurse
#
#
# title: wireman ( freshy ),
#  label: factory hand,
#  real: instrumentation engineer
#
#
# title: skincare solution apprentice,
#  label: nurse assistant,
#  real: aesthetician
#
#
# title: cleaner / general worker,
#  label: building cleaner,
#  real: domestic cleaner
#
#
# title: technician - maintenance,
#  label: maintenance and repair engineer,
#  real: maintenance and repair engineer
#
#
# title: java fullstack software engineer,
#  label: software developer,
#  real: software developer
#
#
# title: project executive,
#  label: project manager,
#  real: management assistant
#
#
# title: project team leader,
#  label: project manager,
#  real: project manager
#
#
# --------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 # metric = load_metric("accuracy")
#       2 model.eval()
# ----> 3 for batch in train_dataloader:
#       4     batch = {k: v.to(device) for k, v in batch.items()}
#       5     with torch.no_grad():
#
# File ~\miniconda3\envs\aml\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\miniconda3\envs\aml\lib\site-packages\torch\utils\data\dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~\miniconda3\envs\aml\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~\miniconda3\envs\aml\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\arrow_dataset.py:1764, in Dataset.__getitem__(self, key)
#    1762 def __getitem__(self, key):  # noqa: F811
#    1763     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 1764     return self._getitem(
#    1765         key,
#    1766     )
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\arrow_dataset.py:1749, in Dataset._getitem(self, key, decoded, **kwargs)
#    1747 formatter = get_formatter(format_type, features=self.features, decoded=decoded, **format_kwargs)
#    1748 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 1749 formatted_output = format_table(
#    1750     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    1751 )
#    1752 return formatted_output
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\formatting.py:532, in format_table(table, key, formatter, format_columns, output_all_columns)
#     530 python_formatter = PythonFormatter(features=None)
#     531 if format_columns is None:
# --> 532     return formatter(pa_table, query_type=query_type)
#     533 elif query_type == "column":
#     534     if key in format_columns:
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\formatting.py:281, in Formatter.__call__(self, pa_table, query_type)
#     279 def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     280     if query_type == "row":
# --> 281         return self.format_row(pa_table)
#     282     elif query_type == "column":
#     283         return self.format_column(pa_table)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\torch_formatter.py:58, in TorchFormatter.format_row(self, pa_table)
#      56 def format_row(self, pa_table: pa.Table) -> dict:
#      57     row = self.numpy_arrow_extractor().extract_row(pa_table)
# ---> 58     return self.recursive_tensorize(row)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\torch_formatter.py:54, in TorchFormatter.recursive_tensorize(self, data_struct)
#      53 def recursive_tensorize(self, data_struct: dict):
# ---> 54     return map_nested(self._recursive_tensorize, data_struct, map_list=False)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\utils\py_utils.py:314, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, types, disable_tqdm, desc)
#     312     num_proc = 1
#     313 if num_proc <= 1 or len(iterable) <= num_proc:
# --> 314     mapped = [
#     315         _single_map_nested((function, obj, types, None, True, None))
#     316         for obj in logging.tqdm(iterable, disable=disable_tqdm, desc=desc)
#     317     ]
#     318 else:
#     319     split_kwds = []  # We organize the splits ourselve (contiguous splits)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\utils\py_utils.py:315, in <listcomp>(.0)
#     312     num_proc = 1
#     313 if num_proc <= 1 or len(iterable) <= num_proc:
#     314     mapped = [
# --> 315         _single_map_nested((function, obj, types, None, True, None))
#     316         for obj in logging.tqdm(iterable, disable=disable_tqdm, desc=desc)
#     317     ]
#     318 else:
#     319     split_kwds = []  # We organize the splits ourselve (contiguous splits)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\utils\py_utils.py:251, in _single_map_nested(args)
#     249 # Singleton first to spare some computation
#     250 if not isinstance(data_struct, dict) and not isinstance(data_struct, types):
# --> 251     return function(data_struct)
#     253 # Reduce logging to keep things readable in multiprocessing with tqdm
#     254 if rank is not None and logging.get_verbosity() < logging.WARNING:
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\torch_formatter.py:51, in TorchFormatter._recursive_tensorize(self, data_struct)
#      49     if data_struct.dtype == np.object:  # pytorch tensors cannot be instantied from an array of objects
#      50         return [self.recursive_tensorize(substruct) for substruct in data_struct]
# ---> 51 return self._tensorize(data_struct)
#
# File ~\miniconda3\envs\aml\lib\site-packages\datasets\formatting\torch_formatter.py:43, in TorchFormatter._tensorize(self, value)
#      40 elif np.issubdtype(value.dtype, np.floating):
#      41     default_dtype = {"dtype": torch.float32}
# ---> 43 return torch.tensor(value, **{**default_dtype, **self.torch_tensor_kwargs})
#
# KeyboardInterrupt:

# %% [markdown]
# idx_to_label
